# %%
import pandas as pd

# %%
weather_df = pd.read_csv(r"D:\PROJETS\ENERGY_PROJECTS\energy-day-ahead-optimizer\data\raw\weather_power_2026-04-26.csv",
                         sep = ",",
                         header = 0)
prices = pd.read_csv(r"D:\PROJETS\ENERGY_PROJECTS\energy-day-ahead-optimizer\data\raw\da_prices_da_price_eur_mwh_2026-04-26_dates.csv",
                     sep = ",", 
                     header = 0)

# %%
weather_df.columns
# Out:
# Index(['slot', 'date', 'temperature_2m', 'apparent_temperature',
#        'wind_speed_10m', 'wind_speed_80m', 'direct_radiation', 'precipitation',
#        'visibility', 'wind_power_mw', 'solar_power_mw'],
#       dtype='object')

# %%
prices.head()
# Out:
#    Unnamed: 0                       date  da_price_eur_mwh
# 0           0  2026-04-26 00:00:00+02:00             80.70
# 1           1  2026-04-26 00:15:00+02:00             58.71
# 2           2  2026-04-26 00:30:00+02:00             26.76
# 3           3  2026-04-26 00:45:00+02:00              0.10
# 4           4  2026-04-26 01:00:00+02:00             26.00

# %%
import pulp

print(pulp.listSolvers(onlyAvailable=True))
# Out:
# ['PULP_CBC_CMD']
